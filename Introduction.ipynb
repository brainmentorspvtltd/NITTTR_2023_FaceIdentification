# %%
# Computer Vision
import cv2

# %%
img = cv2.imread('Avengers-Endgame-Film-Review.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# BGR - opencv uses BGR instead of RGB
# img

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
# Out:
# -1

# %%
import numpy as np

# %%
random_img = np.random.randint(0,255,(500,500,3))

# %%
img.shape
# Out:
# (1125, 1500, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(random_img)
